# %% [markdown]
# <a href="https://colab.research.google.com/github/Hibrul-Anam-Prantik/Machine-Learning/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello ML!")
# Out:
# Hello ML!

# %% [markdown]
# # Testing
